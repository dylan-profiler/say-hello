# %% [markdown]
# # Vektis

# %%
import pandas as pd

from visions.core.functional import type_inference_report_frame, compare_detect_inference_frame
from visions.core.implementations import visions_standard_set
from visions.core.implementations.types import *
from visions.core.model.type import evolve_relation
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df = pd.read_csv('../data/vektis/postcodes_2017.csv', sep=';', low_memory=False)
df.sample(10)
# Out:
#        GESLACHT LEEFTIJDSKLASSE  POSTCODE_3  AANTAL_BSN  \
# 81519         V              24       445.0          63
# 2999          M              11       956.0          55
# 87953         V              31       953.0          29
# 113170        V              61       785.0          27
# 18299         M               3       980.0          71
# 46033         M              63       140.0         182
# 111079        V               6       150.0         434
# 45296         M              62       179.0          96
# 93668         V              39       545.0          58
# 128593        V              80       139.0          86
#
#         AANTAL_VERZEKERDEJAREN  KOSTEN_MEDISCH_SPECIALISTISCHE_ZORG  \
# 81519                    61.84                             54755.50
# 2999                     54.63                             69211.28
# 87953                    29.00                             27718.18
# 113170                   27.00                             30199.27
# ...

# %% [markdown]
# Kosten zijn altijd .2 decimals, store as int (*100)

# %%
df.dtypes
# Out:
# GESLACHT                                   object
# LEEFTIJDSKLASSE                            object
# POSTCODE_3                                float64
# AANTAL_BSN                                  int64
# AANTAL_VERZEKERDEJAREN                    float64
# KOSTEN_MEDISCH_SPECIALISTISCHE_ZORG       float64
# KOSTEN_FARMACIE                           float64
# KOSTEN_SPECIALISTISCHE_GGZ                float64
# KOSTEN_HUISARTS_INSCHRIJFTARIEF           float64
# KOSTEN_HUISARTS_CONSULT                   float64
# KOSTEN_HUISARTS_MDZ                       float64
# KOSTEN_HUISARTS_OVERIG                    float64
# KOSTEN_HULPMIDDELEN                       float64
# KOSTEN_MONDZORG                           float64
# KOSTEN_PARAMEDISCHE_ZORG_FYSIOTHERAPIE    float64
# KOSTEN_PARAMEDISCHE_ZORG_OVERIG           float64
# KOSTEN_ZIEKENVERVOER_ZITTEND              float64
# KOSTEN_ZIEKENVERVOER_LIGGEND              float64
# KOSTEN_KRAAMZORG                          float64
# ...

# %%
typeset = visions_standard_set()

report = type_inference_report_frame(df, typeset)
print(report)
# Out:
# GESLACHT                                    visions_string                 == visions_string
# KOSTEN_HULPMIDDELEN                         visions_float                  == visions_float
# KOSTEN_KRAAMZORG                            visions_float                  == visions_float
# KOSTEN_MEDISCH_SPECIALISTISCHE_ZORG         visions_float                  == visions_float
# KOSTEN_HUISARTS_OVERIG                      visions_float                  == visions_float
# KOSTEN_GRENSOVERSCHRIJDENDE_ZORG            visions_float                  == visions_float
# KOSTEN_FARMACIE                             visions_float                  == visions_float
# KOSTEN_VERLOSKUNDIGE_ZORG                   visions_float                  == visions_float
# KOSTEN_LANGDURIGE_GGZ                       visions_float                  == visions_float
# LEEFTIJDSKLASSE                             visions_string                 == visions_string
# ...
